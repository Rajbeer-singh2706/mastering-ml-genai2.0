# %% [markdown]
# ## **NUMPY 3**

# %%
## what is difference between array and matrix ?
## VEctorization ?

# %%
##

# %%
import numpy as np

# %%
## Matrix Mulitplication #####

# %%
### AGGREGATION ########
## mean 
## sum 
## median 
## standard Deviation  ==> ? 
## CUMULATIVE SUM 
## np.dot ===> @
