# %%
## Topic Covered 
## 1. String Methods
   ## upper()/lower() , title(), capitalize(), swapcase()
   ## strip(), split(), find()
   ## join() 

## 2. While Loop 
## 3. Control Flow  [ Continue, break]
## 4. Functions

# %%
def our_custom_string_cleaner():
    base_string = input("Enter any text: ")
    new_base_string = base_string.strip().lower()
    #print(new_base_string)

    return new_base_string


#dummy_add_two_numbers()

# %%
cleaned_version = our_custom_string_cleaner()
print(cleaned_version)
# Out:
# sdfskjdlasdas

# %%
count = 0 
while count < 5:
    our_custom_string_cleaner()
    count+=1
# Out:
# 123123
# sfdsfsds
# sdasdas
# asdasd
# asdasd
