# %%
a = 1 
b =12.0
c = "tda"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140712085744056
# 2057504890896
# 2057508690160

# %%
# doc string -> document string

# %%
## Operators 
'''
 # 
'''

# %%
# floor divion
22 // 2
# Out:
# 11

# %%
# Divion 
22 / 2
# Out:
# 11.0

# %%
# to run the script 

# uv run
