# %%
#################### Installation ############################

# pip install uv
# OPEN VS CODE WITH THIS Folder
# E:\TEST_UV\level01>
 
# uv python install 3.12
# uv python pin 3.12 
# uv run python

# uv init 
  #* Here u can chnage the name of kernal in pyproject.yaml
# uv add ipykernel
# uv add pandas 
## OR 
## uv sync

# %%
print("HELLO")
# Out:
# HELLO

# %%
###### instruction.txt #######
# create virtual environment
option-1 : uv venv
option-2 : uv venv environment_name

# Run python file (.py)
option-1 : uv run python file.py
option-2 : 
          Step 1 : environment_name\Scripts\activate
	  Step 2 : python file.py

# if kernels keep looping in "detecting"

run this command after activating your environment in terminal : 
command-1 : python -m ensurepip --upgrade
command-2 : python -m pip install ipykernel

# %%
E:\PROJECTS_DIR> 
uv init 
pyproject.toml
-----------------
dependencies = [
     "ipykernel>=7.2.0",
    "pandas>=2.3.3",
    "pymupdf==1.27.2.2",
    "pillow==12.1.1",
    "python-dotenv==1.2.2",
    "streamlit==1.55.0" 
]

uv sync

.venv\Scripts\activate
# uv venv  ===> this create venv , which holds all over liraries

# %%
######
# E:\UDSUltimate2.0_repo>
# mkdir level01  ## Here we are going to do coding
# cd level01 
# uv 
# cls 
# uv python install 3.12
# uv python pin 3.12 
# uv run python
# uv venv        ===> this create venv , which holds all over liraries
# VS CODE Extension ===> Pythonm, Jupyter


#  .venv\Scripts\activate
# Out:
# Running cells with 'Python 3.12.12' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/comp n/AppData/Roaming/uv/python/cpython-3.12.12-windows-x86_64-none/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## TOOLS to INstll

# %%
# mkdir level01
# cd level01

# uv python install 3.14.3
# uv python pin 3.14.3

# uv init

# uv venv

# uv add ipykernel
# uv add pandas

# %%
uv run python -m ipykernel install --user --name level01

# %%
## 14 JAN
UV installation link :
https://docs.astral.sh/uv/getting-started/installation/#standalone-installer

VS code installation link : 
https://code.visualstudio.com/download
