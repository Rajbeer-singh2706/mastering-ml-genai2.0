# %%
### TOPIC COvered ####
# Non Primitve Data types : 
  ## 1. List   [ append(), pop(): removeFromBeginneing, , remove(element), insert(index, element)]
  ## 2. Dictionary ==> [ get() , keys() , values() ]
  ## 3. tuple ===> [ tuple(),  ]
  ## 4. set ===>   [ add() , ]

# len()
# sorted(<>, reverse=True/False )

# %%
alpha = {"a", "b", "d", "z", "g"}
alpha
# Out:
# {'a', 'b', 'd', 'g', 'z'}

# %%
print(type(alpha))
# Out:
# <class 'set'>

# %%
alpha = sorted(alpha)
print(alpha)
# Out:
# ['a', 'b', 'd', 'g', 'z']

# %%
alpha_revers = sorted(alpha, reverse=True)
print(alpha_revers)
# Out:
# ['z', 'g', 'd', 'b', 'a']

# %%
sorted([1,2,3,100,2])
# Out:
# [1, 2, 2, 3, 100]
