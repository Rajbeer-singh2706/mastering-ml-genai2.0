# %%
## Streamlit 
'''
 * set_page_config()
 * title()
 * subheader()

 * write()
 
 * tabs()
 * columns()
 * divider()
 * container()

 * button()
 * link_button()

 * text_input() / text_input(type = "password")
 * text_area()

 * date_input()
 * file_uploader() / type=["csv","txt"]
'''
