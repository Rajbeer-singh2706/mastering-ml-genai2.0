# %%
## Python Project - Day 1

# %% [markdown]
# * Data Visualization
# * Python
# * Database
# * Streamlit
# * OOP

# %% [markdown]
# ## Future Goals :

# %%
## DocManager
# cd docManager 
#
## python -m venv 
## venv/Scripts/activate
## OR 
## uv pin python 3.14.3 
## uv init
## uv sync #
