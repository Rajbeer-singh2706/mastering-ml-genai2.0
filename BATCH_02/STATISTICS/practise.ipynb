# %%
import numpy as np
import statistics as s

# %%
data = [10, 10, 20, 30, 30, 30, 40, 100, 48]
data  = [ 170 , 180 , 100 , 140 , 190 ]
data
# Out:
# [170, 180, 100, 140, 190]

# %%
len(data)
# Out:
# 5

# %%
np.mean(data)
# Out:
# np.float64(156.0)

# %%
np.median(data)
# Out:
# np.float64(170.0)

# %%
s.mode(data)
# Out:
# 170

# %%
variance = np.var(data)
variance
# Out:
# np.float64(1064.0)

# %%
np.var(data[0:4] , ddof=1)
# Out:
# np.float64(1291.6666666666667)

# %%
np.std(data)
# Out:
# np.float64(32.61901286060018)
