# %%
### Topic Covered 
# 1. What is Statistics

# %%
# Variables (2 types) 
'''
 1. Qualitative - Categorical (Nominal, Ordinal) --> Gender, Country, Color, City, etc.
 2. Quantitative - Numerical (Discrete, Continuous) --> Age, Salary, Height, Weight, etc. --> How many? How much?
'''

# %% [markdown]
# # 📊 Statistics Notes

# %% [markdown]
# ## Definition
#
# **Statistics** is a domain of Mathematics/Science where we focus on **collecting, organising, analyzing & interpreting data** to make decisions.
#
# **Examples:**
# - Avg height in the class?
# - Avg age in the class?
# - What is the chance it will rain tomorrow?
# - If I do more study, will I get better grades?

# %% [markdown]
# ## Key Terms
#
# | Term | Definition |
# |---|---|
# | **Population** | Total group (e.g., all 10 students) |
# | **Sample** | Small part of population (e.g., 5 students) |
# | **Parameter** | Describes the **population** (mean, median, etc.) |
# | **Statistic** | Describes the **sample** |
# | **Variable** | Something we measure → height, rank, marks |
# | **Observation** | One data point |
# | **Data** | Collection of observations (name, height, weight, age) |

# %% [markdown]
# ## Population vs Sample Diagram
#
# ```
# Batch-2
#   ├── (1000) All Students  →  Population
#   │       └── Avg age → describing population
#   │       └── Fresher% → describing population
#   │
#   └── 100 Students (live)  →  Sample
#           └── Avg age → describing population via sample
#           └── Fresher% → describing population via sample
# ```

# %% [markdown]
# ## Sample Rule
#
# > **Bigger the sample → Better the estimate**
#
# ```
# 1000 (marks) → sample:
#     2   → 10, 10        → 10
#     100 → 10,10,20,30   → ?  (50)
# ```
#
# *Like taking a handful from a bag of marbles — the more you take, the better your estimate.*

# %% [markdown]
# ## Variables — 2 Types
#
# ### ✅ Qualitative (Categorical)
# → Gender, City, Class, Subject, Email
#
# ### ✅ Quantitative (Numerical)
# → Age, Height, Marks, Temperature, Battery %, Salary, Distance
# *(Answers: "How much?")*

# %% [markdown]
# ## Clothing Brand Example (for context)
#
# ```
# T-Shirts → XS  S  M  L  XL  XXL
#                 ↑              ↑
#            h, w ← range    h, w → range
#
# Data (sample) → Person → w, h
#                 Person →
# Describe → Statistics
#
# W-axis vs H-axis:
#   max w,h → 1
#       w,h → 2
#       w,h → 3
# ```
#
# *(Illustrates how sample data is described using statistics)*
