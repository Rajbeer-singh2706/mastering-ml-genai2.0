# %%
### Data Type ##

# Revise ===> Numpy , Pandas 

####

# %%
## Measure of Central Tendency ---> Goal is to find the 
## DRAWBACKS  ---> sensitive to Outliers

# %%
## OUTLIER --->

# %%
## AVG ---> MEAN --->

# %%
## Median

# %%
## MODE

# %%
## measure
