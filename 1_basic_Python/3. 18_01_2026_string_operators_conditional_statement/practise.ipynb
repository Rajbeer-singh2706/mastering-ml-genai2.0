# %%
# More Data types 

id_people  = [100, 101,102,103,104, 105]
print(id_people)
# Out:
# [100, 101, 102, 103, 104, 105]

# %%
people = [101,100,102,"A","b",37.4, True]
print(people)
print(type(people))

people.append("Data Science")
print(people)
# Out:
# [101, 100, 102, 'A', 'b', 37.4, True]
# <class 'list'>
# [101, 100, 102, 'A', 'b', 37.4, True, 'Data Science']

# %%
register = []
print(register)
print(type(register))

register.append(["monal", 101,"+91112345567890","visit"])
print(register)
print(type(register))

register.append(["pradeep", 101, "+911234567890", "visit"])
print(register)
print(type(register))
# Out:
# []
# <class 'list'>
# [['monal', 101, '+91112345567890', 'visit']]
# <class 'list'>
# [['monal', 101, '+91112345567890', 'visit'], ['pradeep', 101, '+911234567890', 'visit']]
# <class 'list'>

# %%
dummy = []
dummy.append([1,2,3,4,"hello", "monal", 101]) 
len(dummy)
# Out:
# 1
