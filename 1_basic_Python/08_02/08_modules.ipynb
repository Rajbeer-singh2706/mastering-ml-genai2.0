# %% [markdown]
# ## **MODULES**

# %%
import calculator

# %%
c = calculator.Calculator()

# %%
calculator.hello_world()
# Out:
# helloWorld

# %% [markdown]
# ## **Package**

# %%
## from the folder or package import calc module 
from utils import calc

# %%
c = calc.Calculator()
c
# uv run python temp_1.py

# %% [markdown]
# ## **UTILS2**

# %%
### IMPORT ONE BY ONE  
from utils2 import Calculator
from utils2 import hello_world

c = Calculator()
hello_world()
# Out:
# helloWorld

# %%
### IMPORT ALL 
from utils2 import * 

c = Calculator()
hello_world()
# Out:
# helloWorld

# %% [markdown]
# ## **Library**

# %%
## Create Attendance System 
## Create notes summary system using AI 
## ChatBot

# %%
## SOme simple , intermediate, COmplex Assignment bawed on above?

# %%
### Before 3.3 we were supposed to create __init__.py 
## AFter 3.3+ we dont need know 
## Lets late check what new in python 3.1

# %%
2
