# %% [markdown]
# ## **Property_decorator**

# %% [markdown]
# class Account:

# %%
class Account:
    def __init__(self,balance):
        self.balance = balance
        
    # getter
    @property    
    def balance(self):
        print("cheking")
    
    # setter
    @balance.setter
    def balance(self, value):
        if value < 0:
            print("Security Alert. Balance cannot be negative")
        elif value > 100000000:
            print("Security Alert. Large Traansation require apprval ")
        else:
            print("updating balance")
            self.__balance = value

    @balance.deleter
    def balance(self):
        print("ERROR: YOu cannot delete a bank balance")
# Out:
#   Cell In[1], line 2
#     def __init_-():
#                ^
# SyntaxError: invalid syntax

# %%
def

# %%
a = 10

# %%
id(a)

# %%
del a
