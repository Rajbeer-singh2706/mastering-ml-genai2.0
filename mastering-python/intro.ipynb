# %%
# https://www.youtube.com/watch?v=bPrmA1SEN2k&list=PLZoTAELRMXVNUL99R4bDlVYsncUNvwUBB
# Learn everyday ( Everyday One HOUR)
# Depend on Google

# %%
# Part 1 : 
'''
 * Basic Arithmetic OPerations
 * COntrol and conditional structures 
 * Looping - For , While loops
 * User Input 
 * Strings
 * Integers
 * Floating Values 
 * TypeCastin
'''

# %%
# Part 2: Focus on inbuilt data structures # 3 Days
'''
 * Python String -- inbuilt functions
 * Python list and boolean variables -- inbuilt functions
 * Python Sets -- inbuilt functions
 * Python Dictionarires - -- inbuilt functions
 * Python Tuples - -- inbuilt functions

 * Functions IN python
 * Lambda FUnctions
 * Iterators and Generators 
 * Exception Haling & Import Libraries 
'''

# %%
# Part 3: OOPS is ALL YOU NEDD # 4 Days
'''
 * Classes
 * Object 
 * Method
 * Inheritance
 * Polymorphism
 * Data Abstraction
 * Encapsulation
'''
# Everyday 2 Hours --> to learn each topic

# %%
# Part 4: Libraries with Python # 2 Days
'''
 * Numpy - Play with Arrays
 * Pandas
 * Matplotlib
 * Seaborn
 * Scipy
'''
# Everyday 2 Hours --> to learn each topic

# %%
# Path towards Specilization
'''
 * Framework for Web Development 
 * Framework for Builiding Desktop Application
 * Further Libriaries for machine learning and Deep Learning
'''

# %%
# COmbinied Feramwork & Librairies for Macine 
# Learning and Deep Learning

# Numpy 
# Pandas 
# Flask 
# django
# Dask 
# Scipy
# Matplotlib
# Nvidi CUDA 
# KERAS 
# Caffe 
# PyTorch
# TensorFlow
# Seabor

# %%
# Framwork for Web Development
'''
 * Flask
 * Django
 * Web2Py
 * TurboGears
 * CherryPy
'''
