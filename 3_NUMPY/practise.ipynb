# %%
import numpy as np
import time

# %%
## TOPIC 
# time
'''
  1. perf_counter()
'''

### 2. NUMPY #
'''
  1. + ( add 2 array)
'''

### Creatin Arrays in NUMPY ###
'''
 1. np.array()
'''

# %%
arr_1 = np.array([1,2,3])

print(arr_1)
print(type(arr_1))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>
